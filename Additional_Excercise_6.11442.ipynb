# %%
import pandas as pd

# %% [markdown]
# # 1.Read the dataset using pandas

# %%
tags=pd.read_csv("tags.csv")
ratings=pd.read_csv("ratings.csv")
movies=pd.read_csv("movies.csv")

# %% [markdown]
# # 2.Extract the first row from tags and print its type

# %%
tags.iloc[0,:]
# Out:
# userId                18
# movieId             4141
# tag          Mark Waters
# timestamp     1240597180
# Name: 0, dtype: object

# %%
type(tags.head(0))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 3.Extract row 0, 11, 2000 from tags DataFrame

# %%
tags.iloc[[0,11,2000],:]
# Out:
#       userId  movieId                tag   timestamp
# 0         18     4141        Mark Waters  1240597180
# 11        65     1783      noir thriller  1368149983
# 2000     910    68554  conspiracy theory  1368043943

# %% [markdown]
# # 4.Print index, columns of the DataFrame

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %% [markdown]
# # 5.Calculate descriptive statistics for the 'ratings' column of the ratings DataFrame. Verify using describe()

# %%
ratings.rating.std()
# Out:
# 1.051988919275684

# %%
ratings.rating.max()
# Out:
# 5.0

# %%
ratings.rating.count()
# Out:
# 20000263

# %%
ratings.rating.quantile(q=0.75)
# Out:
# 4.0

# %%
ratings.rating.mean()
# Out:
# 3.5255285642993797

# %%
ratings.rating.describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %% [markdown]
# # 9. Find the average rating of movies

# %%
ratings.rating.mean()
# Out:
# 3.5255285642993797

# %% [markdown]
# # 8. Filter out movies from the movies DataFrame that are of type 'Animation'

# %%
movies.columns

# %%
movies[movies['genres']=='Animation']
# Out:
#        movieId                                              title     genres
# 2503      2588                                   Cloudland (1998)  Animation
# 4906      5002                               Fritz the Cat (1972)  Animation
# 4907      5003            Nine Lives of Fritz the Cat, The (1974)  Animation
# 9455     27738                    Cathedral, The (Katedra) (2002)  Animation
# 9989     32840                                     Vincent (1982)  Animation
# 13444    66335                  Afro Samurai: Resurrection (2009)  Animation
# 13858    69469                        Garfield's Pet Force (2009)  Animation
# 14184    71158                Immigrants (L.A. Dolce Vita) (2008)  Animation
# 14492    72603                            Merry Madagascar (2009)  Animation
# 14578    72927                                 Donkey Xote (2007)  Animation
# 14580    72931                                       Tango (1981)  Animation
# ...

# %% [markdown]
# # 10.Perform an inner join of movies and tags based on movieId

# %%
movies_tags=pd.merge(movies,tags,how='inner',on='movieId')

# %%
movies_tags
# Out:
#         movieId                                          title  \
# 0             1                               Toy Story (1995)
# 1             1                               Toy Story (1995)
# 2             1                               Toy Story (1995)
# 3             1                               Toy Story (1995)
# 4             1                               Toy Story (1995)
# 5             1                               Toy Story (1995)
# 6             1                               Toy Story (1995)
# 7             1                               Toy Story (1995)
# 8             1                               Toy Story (1995)
# 9             1                               Toy Story (1995)
# 10            1                               Toy Story (1995)
# 11            1                               Toy Story (1995)
# 12            1                               Toy Story (1995)
# 13            1                               Toy Story (1995)
# ...

# %% [markdown]
#    # Perform an inner join of movies and tags based on movieId

# %%
movies_rating=pd.merge(ratings,movies,how='inner',on='movieId')

# %%
movies_rating
# Out:
#           userId  movieId  rating   timestamp  \
# 0              1        2     3.5  1112486027
# 1              5        2     3.0   851527569
# 2             13        2     3.0   849082742
# 3             29        2     3.0   835562174
# 4             34        2     3.0   846509384
# 5             54        2     3.0   974918176
# 6             88        2     1.0  1098277938
# 7             91        2     3.5  1112061358
# 8            116        2     2.0  1132728068
# 9            119        2     4.0   845110667
# 10           120        2     1.0   838153425
# 11           124        2     2.0  1134476330
# 12           127        2     3.0   847127455
# 13           128        2     3.0   900720958
# 14           129        2     3.0  1283448701
# 15           131        2     1.0  1238326861
# 16           132        2     3.0  1114172997
# 17           137        2     3.0   992797771
# 18           142        2     4.0   833458658
# ...

# %% [markdown]
# # 11.Print out the 5 movies that belong to the Comedy genre and have rating greater than 4

# %%
rating5=movies_rating[movies_rating['genres']=='Comedy'][movies_rating['rating']>4.0]
rating5.groupby(by='title')['title'].head()
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 190505                                          Clerks (1994)
# 190508                                          Clerks (1994)
# 190509                                          Clerks (1994)
# 190510                                          Clerks (1994)
# 190512                                          Clerks (1994)
# 766651                    Monty Python's Life of Brian (1979)
# 766656                    Monty Python's Life of Brian (1979)
# 766661                    Monty Python's Life of Brian (1979)
# 766663                    Monty Python's Life of Brian (1979)
# 766664                    Monty Python's Life of Brian (1979)
# 1837152                       Ferris Bueller's Day Off (1986)
# 1837162                       Ferris Bueller's Day Off (1986)
# ...

# %% [markdown]
# # 13. Extract year from title e.g. (1995)

# %%
tags=tags_ts
movies_tags=pd.merge(movies,tags,how='inner',on='movieId')
mt_1=movies_tags.iloc[:,[1,6]]
mt_1
# Out:
#                                                 title  year
# 0                                    Toy Story (1995)  2006
# 1                                    Toy Story (1995)  2006
# 2                                    Toy Story (1995)  2006
# 3                                    Toy Story (1995)  2006
# 4                                    Toy Story (1995)  2006
# 5                                    Toy Story (1995)  2006
# 6                                    Toy Story (1995)  2006
# 7                                    Toy Story (1995)  2006
# 8                                    Toy Story (1995)  2006
# 9                                    Toy Story (1995)  2006
# 10                                   Toy Story (1995)  2006
# 11                                   Toy Story (1995)  2006
# 12                                   Toy Story (1995)  2006
# 13                                   Toy Story (1995)  2006
# 14                                   Toy Story (1995)  2006
# ...

# %% [markdown]
# # 15.Sort the tags DataFrame based on timestamp

# %%
tags['timestamp']=tags['timestamp'].apply(pd.to_datetime,unit='s')
tags_ts=tags.sort_values(by='timestamp')
tags_ts
# Out:
#         userId  movieId                              tag           timestamp
# 333932  100371     2788                     monty python 2005-12-24 13:00:10
# 333927  100371     1732                    coen brothers 2005-12-24 13:00:36
# 333924  100371     1206                  stanley kubrick 2005-12-24 13:00:48
# 333923  100371     1193                   jack nicholson 2005-12-24 13:02:51
# 333939  100371     5004                    peter sellers 2005-12-24 13:03:19
# 333922  100371       47                   morgan freeman 2005-12-24 13:03:32
# 333921  100371       47                        brad pitt 2005-12-24 13:03:32
# 333936  100371     4011                        brad pitt 2005-12-24 13:03:51
# 333937  100371     4011                      guy ritchie 2005-12-24 13:03:51
# 333920  100371       32                     bruce willis 2005-12-24 13:04:02
# 333933  100371     2858                     kevin spacey 2005-12-24 13:04:26
# ...

# %% [markdown]
# # 14.Select rows based on timestamps later than 2015-02-01

# %%
start_date = '2015-02-01'
mask=(tags_ts['timestamp']>start_date)
tags_ts1=tags_ts.loc[mask]
tags_ts1
# Out:
#         userId  movieId                              tag           timestamp
# 431961  130446   113565                     christianity 2015-02-01 00:04:03
# 431964  130446   113565                             cult 2015-02-01 00:04:11
# 431965  130446   113565                            drama 2015-02-01 00:04:18
# 431966  130446   113565                 fake documentary 2015-02-01 00:04:26
# 431967  130446   113565                    found footage 2015-02-01 00:04:32
# 431958  130446   113565                       born-again 2015-02-01 00:04:41
# 431970  130446   113565                        Jonestown 2015-02-01 00:04:50
# 431969  130446   113565                           horror 2015-02-01 00:04:55
# 431963  130446   113565                        community 2015-02-01 00:05:10
# 431962  130446   113565                 closed community 2015-02-01 00:05:29
# 431974  130446   113565                          suicide 2015-02-01 00:05:41
# ...

# %% [markdown]
# # 6.Filter out ratings with rating > 5

# %%
ratings_5=ratings[(ratings['rating'])>5]
ratings_5.count()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %% [markdown]
# # 7. Find how many null values, missing values are present. Deal with them. Print out how many rows have been modified.

# %%
tags.isnull().sum()
# Out:
# userId        0
# movieId       0
# tag          16
# timestamp     0
# year          0
# dtype: int64

# %%
tags.isna().sum()
# Out:
# userId        0
# movieId       0
# tag          16
# timestamp     0
# year          0
# dtype: int64

# %%
tags[tags['tag'].isnull()].index.tolist()
# Out:
# [373289,
#  373334,
#  373339,
#  373325,
#  373276,
#  373332,
#  373340,
#  373291,
#  373301,
#  373299,
#  373277,
#  373288,
#  373281,
#  373319,
#  373303,
#  454615]
